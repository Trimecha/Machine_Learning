# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import sys
sys.path.append('../Lab1/')
from lab_ML_supervised import rand_gauss, rand_bi_gauss, rand_clown, rand_checkers, grid_2d, plot_2d, frontiere, mse_loss, gradient, plot_gradient, poly2, collist,\
    symlist, gr_mse_loss, hinge_loss, gr_hinge_loss

# %%
import sklearn 
from sklearn import metrics
from sklearn.lda import LDA

# %%
n1=1000
n2=1000
mu1=[2,2]
mu2=[-2,-2]
sigma1=[10,3]
sigma2=[10,3]
data1=rand_bi_gauss(n1,n2,mu1,mu2,sigma1,sigma2)
dataXtrain=data1[:int(0.8*n1),:2]
dataYtrain=data1[:int(0.8*n2),2]
dataXtest=data1[int(0.8*n1):,:2]
dataYtest=data1[int(0.8*n2):,2]
plt.figure( figsize=(15,10))
plt.title('Data set')
plot_2d(dataX,dataY,w=None)
# Out:
# ../Lab1/lab_ML_supervised.py:110: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if (y!=None):

# %%
lda = LDA()
lda.fit(dataXtrain,dataYtrain)
lda.coef_
lda.intercept_


print ("LDA results:")
print (metrics.classification_report(dataY, lda.predict(dataX)))


#meshgrid creation for visualization
xx,yy=grid_2d(dataXtrain,500)
Z = lda.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Display the result into a color plot, second solution
plt.figure(figsize=(15,10))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)
plt.scatter(dataXtrain[:, 0], dataXtrain[:, 1], c=dataYtrain, edgecolors='k',cmap=plt.cm.Paired, s=100)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Linear Discriminant Analysis")
plt.show()
# Out:
# LDA results:
#              precision    recall  f1-score   support
#
#        -1.0       0.81      0.85      0.83       300
#         1.0       0.85      0.80      0.82       300
#
# avg / total       0.83      0.83      0.83       600

# %%
lda.score(dataXtest,dataYtest)
# Out:
# 0.7533333333333333
